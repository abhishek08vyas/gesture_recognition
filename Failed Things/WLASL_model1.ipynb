# %%
import os
import json
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
import mediapipe as mp
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import cv2
from tqdm import tqdm
import pickle

# %%
class WLASLDataLoader:
    def __init__(self, data_path):
        """
        Initialize the WLASL data loader.
        
        Args:
            data_path (str): Path to the root directory of the WLASL dataset
        """
        self.data_path = data_path
        self.videos_path = os.path.join(data_path, 'videos')
        self.json_path = os.path.join(data_path, 'WLASL_v0.3.json')
        self.class_list_path = os.path.join(data_path, 'wlasl_class_list.txt')
        
    def load_class_list(self):
        """
        Load and parse the class list file with improved error handling.
        Returns a dictionary mapping class names to indices.
        """
        class_map = {}
        print("Loading class list from:", self.class_list_path)
        
        try:
            with open(self.class_list_path, 'r', encoding='utf-8') as f:
                lines = f.readlines()
                
            for line in lines:
                # Skip empty lines
                if not line.strip():
                    continue
                    
                # Try different parsing approaches
                try:
                    # First attempt: split by space
                    parts = line.strip().split()
                    if len(parts) >= 2:
                        idx = int(parts[0])
                        # Join remaining parts as class name in case class name contains spaces
                        class_name = ' '.join(parts[1:])
                        class_map[class_name] = idx
                    else:
                        print(f"Warning: Skipping invalid line: {line.strip()}")
                except ValueError as e:
                    print(f"Warning: Could not parse line: {line.strip()}, Error: {str(e)}")
                    
            if not class_map:
                raise ValueError("No valid classes found in the class list file")
                
            print(f"Successfully loaded {len(class_map)} classes")
            return class_map
            
        except FileNotFoundError:
            print(f"Error: Class list file not found at {self.class_list_path}")
            raise
        except Exception as e:
            print(f"Error loading class list: {str(e)}")
            raise
            
    def load_metadata(self):
        """
        Load and parse the WLASL JSON file with error handling.
        """
        try:
            print("Loading metadata from:", self.json_path)
            with open(self.json_path, 'r', encoding='utf-8') as f:
                metadata = json.load(f)
            print(f"Successfully loaded metadata with {len(metadata)} entries")
            return metadata
        except FileNotFoundError:
            print(f"Error: Metadata file not found at {self.json_path}")
            raise
        except json.JSONDecodeError as e:
            print(f"Error: Invalid JSON in metadata file: {str(e)}")
            raise
        except Exception as e:
            print(f"Error loading metadata: {str(e)}")
            raise
    
    def analyze_dataset(self):
        """
        Analyze the dataset and print statistics with improved error handling.
        """
        try:
            # Load metadata and class map
            metadata = self.load_metadata()
            class_map = self.load_class_list()
            
            print("\nDataset Analysis:")
            print(f"Total number of classes in class list: {len(class_map)}")
            
            # Count videos per class
            videos_per_class = {}
            total_videos = 0
            valid_videos = 0
            missing_videos = []
            
            # Create progress bar for metadata processing
            for entry in tqdm(metadata, desc="Analyzing dataset"):
                gloss = entry['gloss']
                if gloss in class_map:
                    instances = entry['instances']
                    num_instances = len(instances)
                    videos_per_class[gloss] = {
                        'total': num_instances,
                        'available': 0
                    }
                    total_videos += num_instances
                    
                    # Check video existence
                    for instance in instances:
                        video_id = instance['video_id']
                        video_path = os.path.join(self.videos_path, f'{video_id}.mp4')
                        
                        if os.path.exists(video_path):
                            videos_per_class[gloss]['available'] += 1
                            valid_videos += 1
                        else:
                            missing_videos.append((gloss, video_id))
            
            # Print detailed analysis
            print(f"\nDetailed Analysis:")
            print(f"Total videos in metadata: {total_videos}")
            print(f"Actually available videos: {valid_videos}")
            print(f"Missing videos: {total_videos - valid_videos}")
            
            if total_videos > 0:
                print(f"Video availability rate: {(valid_videos/total_videos)*100:.2f}%")
            
            if videos_per_class:
                # Find classes with most and least videos
                max_class = max(videos_per_class.items(), 
                              key=lambda x: x[1]['available'])
                min_class = min(videos_per_class.items(), 
                              key=lambda x: x[1]['available'])
                
                print(f"\nClass Distribution:")
                print(f"Largest class: {max_class[0]} "
                      f"({max_class[1]['available']}/{max_class[1]['total']} videos)")
                print(f"Smallest class: {min_class[0]} "
                      f"({min_class[1]['available']}/{min_class[1]['total']} videos)")
                
                # Calculate average videos per class
                avg_videos = valid_videos / len(videos_per_class)
                print(f"Average available videos per class: {avg_videos:.2f}")
            
            # Print sample of missing videos if any
            if missing_videos:
                print(f"\nSample of missing videos (showing first 5):")
                for gloss, video_id in missing_videos[:5]:
                    print(f"- Class: {gloss}, Video ID: {video_id}")
            
            return videos_per_class
            
        except Exception as e:
            print(f"Error during dataset analysis: {str(e)}")
            raise

# %%
class DataPreprocessor:
    def __init__(self, data_path):
        self.data_loader = WLASLDataLoader(data_path)
        self.mp_holistic = mp.solutions.holistic
        self.metadata = self.data_loader.load_metadata()
        self.class_map = self.data_loader.load_class_list()
        
    def extract_landmarks(self, frame, holistic):
        """Extract pose, face, and hand landmarks from a frame."""
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image)
        
        # Initialize empty arrays for landmarks
        pose = np.zeros(33 * 3)  # 33 pose landmarks
        left_hand = np.zeros(21 * 3)  # 21 hand landmarks
        right_hand = np.zeros(21 * 3)
        
        # Extract pose landmarks
        if results.pose_landmarks:
            for idx, landmark in enumerate(results.pose_landmarks.landmark):
                pose[idx*3:(idx+1)*3] = [landmark.x, landmark.y, landmark.z]
                
        # Extract hand landmarks
        if results.left_hand_landmarks:
            for idx, landmark in enumerate(results.left_hand_landmarks.landmark):
                left_hand[idx*3:(idx+1)*3] = [landmark.x, landmark.y, landmark.z]
                
        if results.right_hand_landmarks:
            for idx, landmark in enumerate(results.right_hand_landmarks.landmark):
                right_hand[idx*3:(idx+1)*3] = [landmark.x, landmark.y, landmark.z]
                
        return np.concatenate([pose, left_hand, right_hand])
    
    def process_video(self, video_path, max_frames=30):
        """Process a video file and extract landmarks."""
        landmarks_sequence = []
        
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        # Calculate frame sampling rate
        sample_every = max(1, frame_count // max_frames)
        
        with self.mp_holistic.Holistic(
            min_detection_confidence=0.5,
            min_tracking_confidence=0.5) as holistic:
            
            frame_idx = 0
            while cap.isOpened() and len(landmarks_sequence) < max_frames:
                ret, frame = cap.read()
                if not ret:
                    break
                    
                if frame_idx % sample_every == 0:
                    landmarks = self.extract_landmarks(frame, holistic)
                    landmarks_sequence.append(landmarks)
                    
                frame_idx += 1
                
        cap.release()
        
        # Pad sequence if necessary
        while len(landmarks_sequence) < max_frames:
            landmarks_sequence.append(np.zeros_like(landmarks_sequence[0]))
            
        return np.array(landmarks_sequence)
    
    def prepare_dataset(self, split=0.2):
        """Prepare the dataset for training using JSON metadata."""
        X = []
        y = []
        
        # Process videos using metadata
        for entry in tqdm(self.metadata, desc="Processing classes"):
            gloss = entry['gloss']
            if gloss not in self.class_map:
                continue
                
            class_idx = self.class_map[gloss]
            
            for instance in tqdm(entry['instances'], 
                               desc=f"Processing videos for {gloss}",
                               leave=False):
                video_id = instance['video_id']
                video_path = os.path.join(self.data_loader.videos_path, f'{video_id}.mp4')
                
                if not os.path.exists(video_path):
                    continue
                    
                try:
                    sequence = self.process_video(video_path)
                    X.append(sequence)
                    y.append(class_idx)
                except Exception as e:
                    print(f"Error processing {video_path}: {str(e)}")
        
        X = np.array(X)
        y = np.array(y)
        
        # Split dataset
        X_train, X_val, y_train, y_val = train_test_split(
            X, y, test_size=split, random_state=42)
        
        return X_train, X_val, y_train, y_val

# %%
class SignLanguageModel:
    def __init__(self, num_classes, sequence_length, feature_dim):
        self.num_classes = num_classes
        self.sequence_length = sequence_length
        self.feature_dim = feature_dim
        
    def build_model(self):
        """Build the hybrid CNN-LSTM model."""
        # Input layer
        input_layer = layers.Input(shape=(self.sequence_length, self.feature_dim))
        
        # 1D CNN layers
        x = layers.Conv1D(64, 3, padding='same', activation='relu')(input_layer)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling1D(2)(x)
        
        x = layers.Conv1D(128, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling1D(2)(x)
        
        # LSTM layers
        x = layers.LSTM(256, return_sequences=True)(x)
        x = layers.Dropout(0.3)(x)
        x = layers.LSTM(128)(x)
        x = layers.Dropout(0.3)(x)
        
        # Dense layers
        x = layers.Dense(128, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.3)(x)
        
        # Output layer
        output_layer = layers.Dense(self.num_classes, activation='softmax')(x)
        
        # Create model
        model = models.Model(inputs=input_layer, outputs=output_layer)
        return model
    
    def compile_model(self, model):
        """Compile the model with appropriate optimizer and loss function."""
        optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )
        return model
    
    def train_model(self, model, X_train, y_train, X_val, y_val, 
                    epochs=50, batch_size=32):
        """Train the model with early stopping."""
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True
        )
        
        # Add TQDM progress bar
        class TQDMCallback(tf.keras.callbacks.Callback):
            def on_epoch_begin(self, epoch, logs=None):
                print(f'\nEpoch {epoch+1}/{epochs}')
                self.tqdm = tqdm(total=len(X_train)//batch_size, 
                               desc='Training', leave=False)

            def on_batch_end(self, batch, logs=None):
                self.tqdm.update(1)

            def on_epoch_end(self, epoch, logs=None):
                self.tqdm.close()
                
        history = model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[early_stopping, TQDMCallback()],
            verbose=0
        )
        
        return history

# %%
DATA_PATH = "./WLASL/"  # Update with your dataset path

try:
    # Initialize data loader
    data_loader = WLASLDataLoader(DATA_PATH)
    # Analyze dataset
    print("Starting dataset analysis...")
    videos_per_class = data_loader.analyze_dataset()
    print("\nAnalysis completed successfully!")

except Exception as e:
    print(f"Error in main execution: {str(e)}")
# Out:
# Starting dataset analysis...
# Loading metadata from: ./WLASL/WLASL_v0.3.json
# Successfully loaded metadata with 2000 entries
# Loading class list from: ./WLASL/wlasl_class_list.txt
# Successfully loaded 2000 classes
#
# Dataset Analysis:
# Total number of classes in class list: 2000
# Analyzing dataset: 100%|██████████████████████████████████████████████████████████| 2000/2000 [00:04<00:00, 480.77it/s]
# Detailed Analysis:
# Total videos in metadata: 21067
# Actually available videos: 11971
# Missing videos: 9096
# Video availability rate: 56.82%
#
# Class Distribution:
# Largest class: before (16/26 videos)
# Smallest class: gloves (2/10 videos)
# Average available videos per class: 5.99
#
# Sample of missing videos (showing first 5):
# - Class: book, Video ID: 65225
# - Class: book, Video ID: 68011
# - Class: book, Video ID: 68208
# - Class: book, Video ID: 68012
# - Class: book, Video ID: 70212
#
# Analysis completed successfully!

# %%
# Initialize preprocessor and prepare dataset
print("\nPreparing dataset...")
preprocessor = DataPreprocessor(DATA_PATH)
X_train, X_val, y_train, y_val = preprocessor.prepare_dataset()
# Out:
# Preparing dataset...
# Loading metadata from: ./WLASL/WLASL_v0.3.json
# Successfully loaded metadata with 2000 entries
# Loading class list from: ./WLASL/wlasl_class_list.txt
# Successfully loaded 2000 classes
# Processing classes:   0%|                                                                     | 0/2000 [00:00<?, ?it/s]
# Processing videos for book:   0%|                                                               | 0/40 [00:00<?, ?it/s]C:\Users\abhis\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
#
# Processing videos for book:   2%|█▍                                                     | 1/40 [00:04<02:43,  4.19s/it]
# Processing videos for book:  28%|██████████████▊                                       | 11/40 [00:08<00:18,  1.54it/s]
# Processing videos for book:  45%|████████████████████████▎                             | 18/40 [00:11<00:13,  1.68it/s]
# Processing videos for book:  57%|███████████████████████████████                       | 23/40 [00:15<00:11,  1.54it/s]
# Processing videos for book:  62%|█████████████████████████████████▊                    | 25/40 [00:19<00:13,  1.15it/s]
# Processing videos for book:  75%|████████████████████████████████████████▌             | 30/40 [00:23<00:08,  1.19it/s]
# Processing classes:   0%|                                                          | 1/2000 [00:23<13:13:37, 23.82s/it]
# Processing videos for drink:   0%|                                                              | 0/35 [00:00<?, ?it/s]
# Processing videos for drink:   3%|█▌                                                    | 1/35 [00:04<02:38,  4.65s/it]
# Processing videos for drink:   6%|███                                                   | 2/35 [00:08<02:14,  4.08s/it]
# Processing videos for drink:  34%|██████████████████▏                                  | 12/35 [00:12<00:17,  1.31it/s]
# Processing videos for drink:  49%|█████████████████████████▋                           | 17/35 [00:15<00:13,  1.30it/s]
# Processing videos for drink:  51%|███████████████████████████▎                         | 18/35 [00:19<00:18,  1.07s/it]
# Processing videos for drink:  54%|████████████████████████████▊                        | 19/35 [00:23<00:22,  1.41s/it]
# Processing videos for drink:  57%|██████████████████████████████▎                      | 20/35 [00:27<00:26,  1.75s/it]
# Processing videos for drink:  60%|███████████████████████████████▊                     | 21/35 [00:31<00:30,  2.18s/it]
# Processing videos for drink:  63%|█████████████████████████████████▎                   | 22/35 [00:35<00:32,  2.52s/it]
# Processing videos for drink:  80%|██████████████████████████████████████████▍          | 28/35 [00:39<00:09,  1.33s/it]
# Processing videos for drink:  89%|██████████████████████████████████████████████▉      | 31/35 [00:42<00:05,  1.28s/it]
# Processing videos for drink:  91%|████████████████████████████████████████████████▍    | 32/35 [00:46<00:04,  1.58s/it]
# Processing videos for drink:  94%|█████████████████████████████████████████████████▉   | 33/35 [00:49<00:03,  1.93s/it]
# Processing videos for drink:  97%|███████████████████████████████████████████████████▍ | 34/35 [00:53<00:02,  2.28s/it]
# Processing videos for drink: 100%|█████████████████████████████████████████████████████| 35/35 [00:57<00:00,  2.60s/it]
# Processing classes:   0%|                                                          | 2/2000 [01:21<24:15:56, 43.72s/it]
# Processing videos for computer:   0%|                                                           | 0/30 [00:00<?, ?it/s]
# Processing videos for computer:  13%|██████▊                                            | 4/30 [00:04<00:26,  1.01s/it]
# Processing videos for computer:  23%|███████████▉                                       | 7/30 [00:08<00:28,  1.26s/it]
# Processing videos for computer:  43%|█████████████████████▋                            | 13/30 [00:12<00:14,  1.14it/s]
# Processing videos for computer:  50%|█████████████████████████                         | 15/30 [00:15<00:16,  1.09s/it]
# Processing videos for computer:  53%|██████████████████████████▋                       | 16/30 [00:20<00:21,  1.52s/it]
# Processing videos for computer:  57%|████████████████████████████▎                     | 17/30 [00:24<00:25,  1.99s/it]
# Processing videos for computer:  60%|██████████████████████████████                    | 18/30 [00:28<00:28,  2.36s/it]
# Processing videos for computer:  63%|███████████████████████████████▋                  | 19/30 [00:32<00:29,  2.72s/it]
# Processing videos for computer:  67%|█████████████████████████████████▎                | 20/30 [00:36<00:30,  3.07s/it]
# Processing videos for computer:  70%|███████████████████████████████████               | 21/30 [00:40<00:29,  3.30s/it]
# Processing videos for computer:  73%|████████████████████████████████████▋             | 22/30 [00:44<00:28,  3.50s/it]
# Processing videos for computer:  77%|██████████████████████████████████████▎           | 23/30 [00:48<00:24,  3.57s/it]
# Processing videos for computer:  97%|████████████████████████████████████████████████▎ | 29/30 [00:52<00:01,  1.48s/it]
# Processing videos for computer: 100%|██████████████████████████████████████████████████| 30/30 [00:55<00:00,  1.78s/it]
# Processing classes:   0%|                                                          | 3/2000 [02:17<27:16:58, 49.18s/it]
# Processing videos for before:   0%|                                                             | 0/26 [00:00<?, ?it/s]
# Processing videos for before:  23%|████████████▏                                        | 6/26 [00:03<00:12,  1.62it/s]
# Processing videos for before:  35%|██████████████████▎                                  | 9/26 [00:07<00:15,  1.12it/s]
# Processing videos for before:  38%|████████████████████                                | 10/26 [00:11<00:21,  1.35s/it]
# Processing videos for before:  42%|██████████████████████                              | 11/26 [00:15<00:28,  1.92s/it]
# Processing videos for before:  46%|████████████████████████                            | 12/26 [00:19<00:34,  2.43s/it]
# Processing videos for before:  50%|██████████████████████████                          | 13/26 [00:23<00:34,  2.68s/it]
# Processing videos for before:  54%|████████████████████████████                        | 14/26 [00:27<00:37,  3.09s/it]
# Processing videos for before:  58%|█████████████████████████████▉                      | 15/26 [00:31<00:36,  3.31s/it]
# Processing videos for before:  62%|████████████████████████████████                    | 16/26 [00:35<00:34,  3.42s/it]
# Processing videos for before:  65%|██████████████████████████████████                  | 17/26 [00:38<00:31,  3.50s/it]
# Processing videos for before:  77%|████████████████████████████████████████            | 20/26 [00:43<00:14,  2.35s/it]
# Processing videos for before:  85%|████████████████████████████████████████████        | 22/26 [00:46<00:08,  2.16s/it]
# Processing videos for before:  88%|██████████████████████████████████████████████      | 23/26 [00:50<00:07,  2.44s/it]
# Processing videos for before:  92%|████████████████████████████████████████████████    | 24/26 [00:53<00:05,  2.69s/it]
# Processing videos for before:  96%|██████████████████████████████████████████████████  | 25/26 [00:57<00:02,  2.86s/it]
# Processing videos for before: 100%|████████████████████████████████████████████████████| 26/26 [01:00<00:00,  3.06s/it]
# Processing classes:   0%|                                                          | 4/2000 [03:18<29:51:07, 53.84s/it]
# Processing videos for chair:   0%|                                                              | 0/26 [00:00<?, ?it/s]
# Processing videos for chair:  31%|████████████████▌                                     | 8/26 [00:03<00:08,  2.07it/s]
# Processing videos for chair:  38%|████████████████████▍                                | 10/26 [00:07<00:13,  1.17it/s]
# Processing videos for chair:  42%|██████████████████████▍                              | 11/26 [00:12<00:21,  1.45s/it]
# Processing videos for chair:  46%|████████████████████████▍                            | 12/26 [00:16<00:28,  2.00s/it]
# Processing videos for chair:  50%|██████████████████████████▌                          | 13/26 [00:20<00:31,  2.43s/it]
# Processing videos for chair:  54%|████████████████████████████▌                        | 14/26 [00:24<00:32,  2.74s/it]
# Processing videos for chair:  62%|████████████████████████████████▌                    | 16/26 [00:28<00:23,  2.39s/it]
# Processing classes:   0%|▏                                                         | 5/2000 [03:46<24:43:40, 44.62s/it]
# Processing videos for go:   0%|                                                                 | 0/26 [00:00<?, ?it/s]
# Processing videos for go:   8%|████▍                                                    | 2/26 [00:04<00:48,  2.04s/it]
# Processing videos for go:  15%|████████▊                                                | 4/26 [00:07<00:42,  1.94s/it]
# Processing videos for go:  19%|██████████▉                                              | 5/26 [00:11<00:51,  2.46s/it]
# Processing videos for go:  23%|█████████████▏                                           | 6/26 [00:15<00:57,  2.88s/it]
# Processing videos for go:  27%|███████████████▎                                         | 7/26 [00:19<01:00,  3.19s/it]
# Processing videos for go:  31%|█████████████████▌                                       | 8/26 [00:22<00:59,  3.31s/it]
# Processing videos for go:  35%|███████████████████▋                                     | 9/26 [00:26<00:57,  3.41s/it]
# Processing videos for go:  58%|████████████████████████████████▎                       | 15/26 [00:30<00:15,  1.45s/it]
# Processing videos for go:  62%|██████████████████████████████████▍                     | 16/26 [00:34<00:18,  1.85s/it]
# Processing videos for go:  65%|████████████████████████████████████▌                   | 17/26 [00:39<00:20,  2.27s/it]
# Processing videos for go:  69%|██████████████████████████████████████▊                 | 18/26 [00:43<00:21,  2.68s/it]
# Processing videos for go:  73%|████████████████████████████████████████▉               | 19/26 [00:47<00:20,  2.98s/it]
# Processing videos for go:  81%|█████████████████████████████████████████████▏          | 21/26 [00:51<00:12,  2.59s/it]
# Processing videos for go:  96%|█████████████████████████████████████████████████████▊  | 25/26 [00:55<00:01,  1.73s/it]
# Processing videos for go: 100%|████████████████████████████████████████████████████████| 26/26 [00:59<00:00,  2.06s/it]
# Processing classes:   0%|▏                                                         | 6/2000 [04:45<27:25:58, 49.53s/it]
# Processing videos for clothes:   0%|                                                            | 0/25 [00:00<?, ?it/s]
# Processing videos for clothes:  24%|████████████▍                                       | 6/25 [00:04<00:13,  1.36it/s]
# Processing videos for clothes:  32%|████████████████▋                                   | 8/25 [00:08<00:19,  1.14s/it]
# Processing videos for clothes:  36%|██████████████████▋                                 | 9/25 [00:12<00:26,  1.64s/it]
# Processing videos for clothes:  44%|██████████████████████▍                            | 11/25 [00:16<00:24,  1.76s/it]
# Processing videos for clothes:  56%|████████████████████████████▌                      | 14/25 [00:20<00:17,  1.61s/it]
# Processing classes:   0%|▏                                                         | 7/2000 [05:05<22:09:09, 40.01s/it]
# Processing videos for who:   0%|                                                                | 0/25 [00:00<?, ?it/s]
# Processing videos for who:   8%|████▍                                                   | 2/25 [00:04<00:46,  2.01s/it]
# Processing videos for who:  32%|█████████████████▉                                      | 8/25 [00:07<00:15,  1.12it/s]
# Processing videos for who:  36%|████████████████████▏                                   | 9/25 [00:11<00:22,  1.42s/it]
# Processing videos for who:  40%|██████████████████████                                 | 10/25 [00:16<00:29,  1.98s/it]
# Processing videos for who:  44%|████████████████████████▏                              | 11/25 [00:21<00:36,  2.59s/it]
# Processing videos for who:  48%|██████████████████████████▍                            | 12/25 [00:25<00:39,  3.06s/it]
# Processing videos for who:  52%|████████████████████████████▌                          | 13/25 [00:30<00:41,  3.46s/it]
# Processing videos for who:  56%|██████████████████████████████▊                        | 14/25 [00:34<00:39,  3.58s/it]
# Processing videos for who:  60%|█████████████████████████████████                      | 15/25 [00:38<00:35,  3.58s/it]
# Processing videos for who:  64%|███████████████████████████████████▏                   | 16/25 [00:41<00:32,  3.63s/it]
# Processing videos for who:  76%|█████████████████████████████████████████▊             | 19/25 [00:45<00:14,  2.34s/it]
# Processing videos for who:  84%|██████████████████████████████████████████████▏        | 21/25 [00:48<00:08,  2.06s/it]
# Processing videos for who:  92%|██████████████████████████████████████████████████▌    | 23/25 [00:52<00:04,  2.05s/it]
# Processing videos for who:  96%|████████████████████████████████████████████████████▊  | 24/25 [00:56<00:02,  2.48s/it]
# Processing classes:   0%|▏                                                         | 8/2000 [06:02<25:07:58, 45.42s/it]
# Processing videos for candy:   0%|                                                              | 0/24 [00:00<?, ?it/s]
# Processing videos for candy:  25%|█████████████▌                                        | 6/24 [00:04<00:13,  1.36it/s]
# Processing videos for candy:  29%|███████████████▊                                      | 7/24 [00:08<00:23,  1.40s/it]
# Processing videos for candy:  33%|██████████████████                                    | 8/24 [00:12<00:32,  2.01s/it]
# Processing videos for candy:  38%|████████████████████▎                                 | 9/24 [00:17<00:38,  2.60s/it]
# Processing videos for candy:  42%|██████████████████████                               | 10/24 [00:21<00:42,  3.03s/it]
# Processing videos for candy:  46%|████████████████████████▎                            | 11/24 [00:26<00:44,  3.40s/it]
# Processing videos for candy:  50%|██████████████████████████▌                          | 12/24 [00:29<00:41,  3.49s/it]
# Processing videos for deaf:  65%|███████████████████████████████████▏                  | 15/23 [00:31<00:25,  3.20s/it]
# Processing videos for deaf:  70%|█████████████████████████████████████▌                | 16/23 [00:35<00:23,  3.33s/it]
# Processing videos for deaf:  83%|████████████████████████████████████████████▌         | 19/23 [00:38<00:08,  2.20s/it]
# Processing videos for deaf:  87%|██████████████████████████████████████████████▉       | 20/23 [00:42<00:07,  2.50s/it]
# Processing classes:   1%|▎                                                        | 11/2000 [08:29<25:55:06, 46.91s/it]
# Processing videos for fine:   0%|                                                               | 0/22 [00:00<?, ?it/s]
# Processing videos for fine:  36%|████████████████████                                   | 8/22 [00:03<00:06,  2.05it/s]
# Processing videos for fine:  45%|████████████████████████▌                             | 10/22 [00:07<00:10,  1.19it/s]
# Processing videos for fine:  50%|███████████████████████████                           | 11/22 [00:11<00:14,  1.29s/it]
# Processing videos for fine:  55%|█████████████████████████████▍                        | 12/22 [00:14<00:17,  1.73s/it]
# Processing videos for fine:  59%|███████████████████████████████▉                      | 13/22 [00:18<00:19,  2.16s/it]
# Processing videos for fine:  64%|██████████████████████████████████▎                   | 14/22 [00:22<00:20,  2.51s/it]
# Processing videos for fine:  68%|████████████████████████████████████▊                 | 15/22 [00:26<00:19,  2.83s/it]
# Processing videos for fine:  82%|████████████████████████████████████████████▏         | 18/22 [00:29<00:07,  2.00s/it]
# Processing videos for fine:  95%|███████████████████████████████████████████████████▌  | 21/22 [00:33<00:01,  1.67s/it]
# Processing classes:   1%|▎                                                        | 12/2000 [09:02<23:39:40, 42.85s/it]
# Processing videos for help:   0%|                                                               | 0/22 [00:00<?, ?it/s]
# Processing videos for help:   9%|█████                                                  | 2/22 [00:04<00:44,  2.22s/it]
# Processing videos for help:  23%|████████████▌                                          | 5/22 [00:08<00:27,  1.62s/it]
# Processing videos for help:  27%|██████████████▉                                        | 6/22 [00:12<00:34,  2.15s/it]
# Processing videos for help:  32%|█████████████████▌                                     | 7/22 [00:16<00:38,  2.60s/it]
# Processing videos for help:  36%|████████████████████                                   | 8/22 [00:19<00:41,  2.94s/it]
# Processing videos for help:  41%|██████████████████████▌                                | 9/22 [00:23<00:40,  3.14s/it]
# Processing videos for help:  59%|███████████████████████████████▉                      | 13/22 [00:27<00:15,  1.77s/it]
# Processing videos for help:  64%|██████████████████████████████████▎                   | 14/22 [00:30<00:16,  2.12s/it]
# Processing videos for help:  68%|████████████████████████████████████▊                 | 15/22 [00:34<00:16,  2.43s/it]
# Processing videos for help:  73%|███████████████████████████████████████▎              | 16/22 [00:38<00:16,  2.71s/it]
# Processing videos for help:  77%|█████████████████████████████████████████▋            | 17/22 [00:42<00:14,  2.98s/it]
# Processing videos for help:  86%|██████████████████████████████████████████████▋       | 19/22 [00:45<00:07,  2.51s/it]
# Processing videos for help:  91%|█████████████████████████████████████████████████     | 20/22 [00:49<00:05,  2.79s/it]
# Processing videos for help:  95%|███████████████████████████████████████████████████▌  | 21/22 [00:53<00:02,  2.99s/it]
# Processing classes:   1%|▎                                                        | 13/2000 [09:55<25:22:23, 45.97s/it]
# Processing videos for walk:  32%|█████████████████▌                                     | 7/22 [00:04<00:08,  1.75it/s]
# Processing videos for walk:  36%|████████████████████                                   | 8/22 [00:07<00:15,  1.09s/it]
# Processing videos for walk:  41%|██████████████████████▌                                | 9/22 [00:11<00:21,  1.64s/it]
# Processing videos for walk:  45%|████████████████████████▌                             | 10/22 [00:15<00:26,  2.17s/it]
# Processing videos for walk:  50%|███████████████████████████                           | 11/22 [00:19<00:27,  2.54s/it]
# Processing videos for walk:  59%|███████████████████████████████▉                      | 13/22 [00:23<00:20,  2.25s/it]
# Processing videos for walk:  68%|████████████████████████████████████▊                 | 15/22 [00:26<00:14,  2.10s/it]
# Processing videos for walk:  73%|███████████████████████████████████████▎              | 16/22 [00:30<00:14,  2.44s/it]
# Processing videos for walk:  82%|████████████████████████████████████████████▏         | 18/22 [00:34<00:08,  2.22s/it]
# Processing videos for walk:  86%|██████████████████████████████████████████████▋       | 19/22 [00:37<00:07,  2.55s/it]
# Processing videos for walk:  91%|█████████████████████████████████████████████████     | 20/22 [00:41<00:05,  2.81s/it]
# Processing classes:   1%|▍                                                        | 16/2000 [12:19<25:58:06, 47.12s/it]
# Processing videos for year:   0%|                                                               | 0/22 [00:00<?, ?it/s]
# Processing videos for year:   9%|█████                                                  | 2/22 [00:04<00:40,  2.04s/it]
# Processing videos for year:  36%|████████████████████                                   | 8/22 [00:07<00:12,  1.10it/s]
# Processing videos for year:  41%|██████████████████████▌                                | 9/22 [00:11<00:17,  1.33s/it]
# Processing videos for year:  45%|████████████████████████▌                             | 10/22 [00:15<00:22,  1.85s/it]
# Processing videos for year:  50%|███████████████████████████                           | 11/22 [00:19<00:24,  2.24s/it]
# Processing videos for year:  55%|█████████████████████████████▍                        | 12/22 [00:22<00:25,  2.58s/it]
# Processing videos for year:  59%|███████████████████████████████▉                      | 13/22 [00:26<00:26,  2.90s/it]
# Processing videos for year:  64%|██████████████████████████████████▎                   | 14/22 [00:30<00:23,  2.99s/it]
# Processing videos for year:  86%|██████████████████████████████████████████████▋       | 19/22 [00:33<00:04,  1.47s/it]
# Processing videos for year:  91%|█████████████████████████████████████████████████     | 20/22 [00:36<00:03,  1.80s/it]
# Processing classes:   1%|▍                                                        | 17/2000 [12:56<24:15:53, 44.05s/it]
# Processing videos for yes:   0%|                                                                | 0/22 [00:00<?, ?it/s]
# Processing videos for yes:   9%|█████                                                   | 2/22 [00:03<00:39,  1.98s/it]
# Processing videos for yes:  14%|███████▋                                                | 3/22 [00:07<00:50,  2.67s/it]
# Processing videos for yes:  27%|███████████████▎                                        | 6/22 [00:11<00:30,  1.88s/it]
# Processing videos for yes:  32%|█████████████████▊                                      | 7/22 [00:15<00:35,  2.33s/it]
# Processing videos for yes:  36%|████████████████████▎                                   | 8/22 [00:19<00:37,  2.69s/it]
# Processing videos for yes:  41%|██████████████████████▉                                 | 9/22 [00:23<00:39,  3.01s/it]
# Processing videos for yes:  59%|████████████████████████████████▌                      | 13/22 [00:26<00:15,  1.74s/it]
# Processing videos for yes:  68%|█████████████████████████████████████▌                 | 15/22 [00:30<00:12,  1.76s/it]
# Processing videos for yes:  82%|█████████████████████████████████████████████          | 18/22 [00:34<00:06,  1.56s/it]
# Processing videos for yes:  86%|███████████████████████████████████████████████▌       | 19/22 [00:38<00:05,  1.90s/it]
# Processing videos for yes:  91%|██████████████████████████████████████████████████     | 20/22 [00:41<00:04,  2.23s/it]
# Processing videos for yes: 100%|███████████████████████████████████████████████████████| 22/22 [00:44<00:00,  1.98s/it]
# Processing classes:   1%|▌                                                        | 18/2000 [13:41<24:22:01, 44.26s/it]
# Processing videos for all:   0%|                                                                | 0/21 [00:00<?, ?it/s]
# Processing videos for all:  10%|█████▎                                                  | 2/21 [00:04<00:42,  2.25s/it]
# Processing videos for all:  29%|████████████████                                        | 6/21 [00:08<00:19,  1.29s/it]
# Processing videos for all:  33%|██████████████████▋                                     | 7/21 [00:12<00:25,  1.82s/it]
# Processing videos for all:  38%|█████████████████████▎                                  | 8/21 [00:15<00:29,  2.23s/it]
# Processing videos for all:  52%|████████████████████████████▊                          | 11/21 [00:19<00:17,  1.73s/it]
# Processing videos for all:  57%|███████████████████████████████▍                       | 12/21 [00:22<00:18,  2.08s/it]
# Processing videos for all:  62%|██████████████████████████████████                     | 13/21 [00:26<00:19,  2.44s/it]
# Processing videos for all:  71%|███████████████████████████████████████▎               | 15/21 [00:30<00:13,  2.20s/it]
# Processing classes:   1%|▌                                                        | 19/2000 [14:11<22:03:35, 40.09s/it]
# Processing videos for black:   0%|                                                              | 0/21 [00:00<?, ?it/s]
# Processing videos for black:  10%|█████▏                                                | 2/21 [00:03<00:37,  1.97s/it]
# Processing videos for black:  24%|████████████▊                                         | 5/21 [00:07<00:23,  1.45s/it]
# Processing videos for black:  29%|███████████████▍                                      | 6/21 [00:11<00:32,  2.14s/it]
# Processing videos for black:  33%|██████████████████                                    | 7/21 [00:15<00:35,  2.54s/it]
# Processing videos for black:  43%|███████████████████████▏                              | 9/21 [00:19<00:26,  2.24s/it]
# Processing videos for black:  48%|█████████████████████████▏                           | 10/21 [00:21<00:25,  2.35s/it]
# Processing videos for black:  52%|███████████████████████████▊                         | 11/21 [00:25<00:26,  2.66s/it]
# Processing videos for black:  62%|████████████████████████████████▊                    | 13/21 [00:29<00:18,  2.32s/it]
# Processing videos for black:  67%|███████████████████████████████████▎                 | 14/21 [00:32<00:18,  2.62s/it]
# Processing videos for black: 100%|█████████████████████████████████████████████████████| 21/21 [00:36<00:00,  1.17s/it]
# Processing classes:   1%|▌                                                        | 20/2000 [14:48<21:27:34, 39.02s/it]
# Processing videos for cool:   0%|                                                               | 0/21 [00:00<?, ?it/s]
# Processing videos for cool:   5%|██▌                                                    | 1/21 [00:03<01:11,  3.58s/it]
# Processing videos for cool:  10%|█████▏                                                 | 2/21 [00:07<01:08,  3.60s/it]
# Processing videos for cool:  19%|██████████▍                                            | 4/21 [00:10<00:42,  2.48s/it]
# Processing videos for cool:  29%|███████████████▋                                       | 6/21 [00:14<00:31,  2.13s/it]
# Processing videos for hot:  57%|███████████████████████████████▍                       | 12/21 [00:31<00:20,  2.29s/it]
# Processing videos for hot:  62%|██████████████████████████████████                     | 13/21 [00:34<00:20,  2.59s/it]
# Processing videos for hot:  67%|████████████████████████████████████▋                  | 14/21 [00:38<00:19,  2.85s/it]
# Processing classes:   1%|▋                                                        | 23/2000 [16:59<22:17:40, 40.60s/it]
# Processing videos for like:   0%|                                                               | 0/21 [00:00<?, ?it/s]
# Processing videos for like:   5%|██▌                                                    | 1/21 [00:03<01:17,  3.86s/it]
# Processing videos for like:  10%|█████▏                                                 | 2/21 [00:07<01:11,  3.76s/it]
# Processing videos for like:  24%|█████████████                                          | 5/21 [00:11<00:31,  1.97s/it]
# Processing videos for like:  29%|███████████████▋                                       | 6/21 [00:15<00:37,  2.49s/it]
# Processing videos for like:  33%|██████████████████▎                                    | 7/21 [00:19<00:39,  2.81s/it]
# Processing videos for like:  38%|████████████████████▉                                  | 8/21 [00:22<00:39,  3.07s/it]
# Processing videos for like:  43%|███████████████████████▌                               | 9/21 [00:26<00:39,  3.28s/it]
# Processing videos for like:  48%|█████████████████████████▋                            | 10/21 [00:30<00:37,  3.41s/it]
# Processing videos for like:  57%|██████████████████████████████▊                       | 12/21 [00:33<00:23,  2.65s/it]
# Processing videos for like:  62%|█████████████████████████████████▍                    | 13/21 [00:37<00:23,  2.89s/it]
# Processing classes:   1%|▋                                                        | 24/2000 [17:36<21:45:33, 39.64s/it]
# Processing videos for many:   0%|                                                               | 0/21 [00:00<?, ?it/s]
# Processing videos for many:  10%|█████▏                                                 | 2/21 [00:03<00:36,  1.92s/it]
# Processing videos for many:  19%|██████████▍                                            | 4/21 [00:07<00:32,  1.89s/it]
# Processing videos for many:  24%|█████████████                                          | 5/21 [00:11<00:39,  2.49s/it]
# Processing videos for many:  29%|███████████████▋                                       | 6/21 [00:15<00:44,  2.98s/it]
# Processing videos for many:  33%|██████████████████▎                                    | 7/21 [00:19<00:45,  3.26s/it]
# Processing videos for many:  38%|████████████████████▉                                  | 8/21 [00:23<00:43,  3.38s/it]
# Processing videos for many:  52%|████████████████████████████▎                         | 11/21 [00:26<00:21,  2.18s/it]
# Processing videos for many:  57%|██████████████████████████████▊                       | 12/21 [00:30<00:22,  2.48s/it]
# Processing videos for many:  67%|████████████████████████████████████                  | 14/21 [00:34<00:15,  2.23s/it]
# Processing videos for many: 100%|██████████████████████████████████████████████████████| 21/21 [00:37<00:00,  1.13s/it]
# Processing classes:   1%|▋                                                        | 25/2000 [18:14<21:28:20, 39.14s/it]
# Processing videos for mother:   0%|                                                             | 0/21 [00:00<?, ?it/s]
# Processing videos for mother:  10%|█████                                                | 2/21 [00:03<00:35,  1.84s/it]
# Processing videos for mother:  19%|██████████                                           | 4/21 [00:07<00:31,  1.87s/it]
# Processing videos for mother:  24%|████████████▌                                        | 5/21 [00:11<00:38,  2.39s/it]
# Processing videos for mother:  29%|███████████████▏                                     | 6/21 [00:15<00:44,  2.96s/it]
# Processing videos for mother:  33%|█████████████████▋                                   | 7/21 [00:19<00:44,  3.16s/it]
# Processing videos for mother:  38%|████████████████████▏                                | 8/21 [00:22<00:43,  3.32s/it]
# Processing videos for mother:  48%|████████████████████████▊                           | 10/21 [00:26<00:29,  2.64s/it]
# Processing videos for mother:  52%|███████████████████████████▏                        | 11/21 [00:30<00:29,  2.91s/it]
# Processing videos for mother:  62%|████████████████████████████████▏                   | 13/21 [00:33<00:19,  2.48s/it]
# Processing videos for mother:  67%|██████████████████████████████████▋                 | 14/21 [00:37<00:19,  2.74s/it]
# Processing videos for mother:  71%|█████████████████████████████████████▏              | 15/21 [00:41<00:17,  2.95s/it]
# Processing classes:   1%|▋                                                        | 26/2000 [18:55<21:47:13, 39.73s/it]
# Processing videos for now:   0%|                                                                | 0/21 [00:00<?, ?it/s]
# Processing videos for now:  10%|█████▎                                                  | 2/21 [00:04<00:39,  2.07s/it]
# Processing videos for now:  14%|████████                                                | 3/21 [00:07<00:49,  2.76s/it]
# Processing videos for now:  38%|█████████████████████▎                                  | 8/21 [00:11<00:16,  1.24s/it]
# Processing videos for now:  43%|████████████████████████                                | 9/21 [00:15<00:20,  1.67s/it]
# Processing videos for now:  62%|██████████████████████████████████                     | 13/21 [00:18<00:10,  1.28s/it]
# Processing videos for now:  81%|████████████████████████████████████████████▌          | 17/21 [00:22<00:04,  1.13s/it]
# Processing videos for now:  86%|███████████████████████████████████████████████▏       | 18/21 [00:26<00:04,  1.47s/it]
# Processing videos for now:  90%|█████████████████████████████████████████████████▊     | 19/21 [00:29<00:03,  1.81s/it]
# Processing videos for now: 100%|███████████████████████████████████████████████████████| 21/21 [00:33<00:00,  1.80s/it]
# Processing classes:   1%|▊                                                        | 27/2000 [19:28<20:44:06, 37.83s/it]
# Processing videos for orange:   0%|                                                             | 0/21 [00:00<?, ?it/s]
# Processing videos for orange:  10%|█████                                                | 2/21 [00:03<00:35,  1.86s/it]
# Processing videos for orange:  29%|███████████████▏                                     | 6/21 [00:07<00:17,  1.15s/it]
# Processing videos for orange:  33%|█████████████████▋                                   | 7/21 [00:11<00:24,  1.73s/it]
# Processing videos for orange:  38%|████████████████████▏                                | 8/21 [00:15<00:29,  2.28s/it]
# Processing videos for orange:  43%|██████████████████████▋                              | 9/21 [00:19<00:31,  2.65s/it]
# Processing videos for orange:  48%|████████████████████████▊                           | 10/21 [00:22<00:32,  2.95s/it]
# Processing videos for orange:  57%|█████████████████████████████▋                      | 12/21 [00:26<00:22,  2.47s/it]
# Processing videos for orange:  71%|█████████████████████████████████████▏              | 15/21 [00:30<00:11,  1.86s/it]
# Processing videos for orange:  95%|█████████████████████████████████████████████████▌  | 20/21 [00:33<00:01,  1.27s/it]
# Processing videos for orange: 100%|████████████████████████████████████████████████████| 21/21 [00:37<00:00,  1.62s/it]
# Processing classes:   1%|▊                                                        | 28/2000 [20:06<20:44:10, 37.86s/it]
# Processing videos for table:   0%|                                                              | 0/21 [00:00<?, ?it/s]
# Processing videos for table:  29%|███████████████▍                                      | 6/21 [00:04<00:11,  1.36it/s]
# Processing videos for table:  48%|█████████████████████████▏                           | 10/21 [00:08<00:08,  1.23it/s]
# Processing videos for table:  52%|███████████████████████████▊                         | 11/21 [00:11<00:12,  1.24s/it]
# Processing videos for table:  57%|██████████████████████████████▎                      | 12/21 [00:15<00:15,  1.72s/it]
# Processing videos for table:  67%|███████████████████████████████████▎                 | 14/21 [00:19<00:12,  1.75s/it]
# Processing classes:   1%|▊                                                        | 29/2000 [20:26<17:40:39, 32.29s/it]
# Processing videos for thanksgiving:   0%|                                                       | 0/21 [00:00<?, ?it/s]
# Processing videos for thanksgiving:  19%|████████▉                                      | 4/21 [00:03<00:16,  1.06it/s]
# Processing videos for thanksgiving:  24%|███████████▏                                   | 5/21 [00:07<00:27,  1.69s/it]
# Processing videos for thanksgiving:  29%|█████████████▍                                 | 6/21 [00:11<00:33,  2.21s/it]
# Processing videos for thanksgiving:  33%|███████████████▋                               | 7/21 [00:14<00:37,  2.66s/it]
# Processing videos for thanksgiving:  38%|█████████████████▉                             | 8/21 [00:18<00:39,  3.00s/it]
# Processing videos for thanksgiving:  43%|████████████████████▏                          | 9/21 [00:21<00:35,  2.95s/it]
# Processing videos for thanksgiving:  48%|█████████████████████▉                        | 10/21 [00:25<00:34,  3.18s/it]
# Processing videos for thanksgiving:  52%|████████████████████████                      | 11/21 [00:29<00:33,  3.38s/it]
# Processing videos for thanksgiving:  62%|████████████████████████████▍                 | 13/21 [00:32<00:21,  2.67s/it]
# Processing videos for thanksgiving:  76%|███████████████████████████████████           | 16/21 [00:36<00:09,  1.95s/it]
# Processing videos for thanksgiving:  81%|█████████████████████████████████████▏        | 17/21 [00:40<00:09,  2.26s/it]
# Processing videos for thanksgiving:  86%|███████████████████████████████████████▍      | 18/21 [00:43<00:07,  2.56s/it]
# Processing videos for thanksgiving:  90%|█████████████████████████████████████████▌    | 19/21 [00:47<00:05,  2.78s/it]
# Processing classes:   2%|▊                                                        | 30/2000 [21:13<20:07:50, 36.79s/it]
# ...
# Processing videos for turn: 100%|████████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.49s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▍| 1979/2000 [13:38:54<06:48, 19.46s/it]
# Processing videos for tv:   0%|                                                                  | 0/7 [00:00<?, ?it/s]
# Processing videos for tv:  14%|████████▎                                                 | 1/7 [00:04<00:28,  4.74s/it]
# Processing videos for tv: 100%|██████████████████████████████████████████████████████████| 7/7 [00:09<00:00,  1.14s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▍| 1980/2000 [13:39:03<05:26, 16.35s/it]
# Processing videos for u:   0%|                                                                   | 0/7 [00:00<?, ?it/s]
# Processing videos for u:  29%|████████████████▊                                          | 2/7 [00:04<00:10,  2.14s/it]
# Processing videos for u:  43%|█████████████████████████▎                                 | 3/7 [00:08<00:12,  3.11s/it]
# Processing videos for u:  71%|██████████████████████████████████████████▏                | 5/7 [00:12<00:05,  2.53s/it]
# Processing videos for u: 100%|███████████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.36s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▍| 1981/2000 [13:39:21<05:15, 16.59s/it]
# Processing videos for unique:   0%|                                                              | 0/7 [00:00<?, ?it/s]
# Processing videos for unique:  29%|███████████████▍                                      | 2/7 [00:04<00:10,  2.11s/it]
# Processing videos for unique:  43%|███████████████████████▏                              | 3/7 [00:08<00:11,  2.99s/it]
# Processing videos for unique:  57%|██████████████████████████████▊                       | 4/7 [00:13<00:10,  3.61s/it]
# Processing videos for unique:  71%|██████████████████████████████████████▌               | 5/7 [00:17<00:07,  3.84s/it]
# Processing videos for unique:  86%|██████████████████████████████████████████████▎       | 6/7 [00:21<00:04,  4.00s/it]
# Processing videos for unique: 100%|██████████████████████████████████████████████████████| 7/7 [00:26<00:00,  4.21s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▌| 1982/2000 [13:39:47<05:51, 19.53s/it]
# Processing videos for upstairs:   0%|                                                            | 0/7 [00:00<?, ?it/s]
# Processing videos for upstairs:  29%|██████████████▊                                     | 2/7 [00:04<00:12,  2.43s/it]
# Processing videos for upstairs:  43%|██████████████████████▎                             | 3/7 [00:09<00:13,  3.27s/it]
# Processing videos for upstairs:  71%|█████████████████████████████████████▏              | 5/7 [00:13<00:05,  2.64s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▌| 1983/2000 [13:40:00<05:01, 17.74s/it]
# Processing videos for v:   0%|                                                                   | 0/7 [00:00<?, ?it/s]
# Processing videos for v:  29%|████████████████▊                                          | 2/7 [00:04<00:11,  2.20s/it]
# Processing videos for v:  43%|█████████████████████████▎                                 | 3/7 [00:08<00:12,  3.15s/it]
# Processing videos for v:  71%|██████████████████████████████████████████▏                | 5/7 [00:13<00:05,  2.65s/it]
# Processing videos for v: 100%|███████████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.44s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▌| 1984/2000 [13:40:18<04:43, 17.74s/it]
# Processing videos for vacant:   0%|                                                              | 0/7 [00:00<?, ?it/s]
# Processing videos for vacant:  29%|███████████████▍                                      | 2/7 [00:04<00:10,  2.19s/it]
# Processing videos for vacant:  43%|███████████████████████▏                              | 3/7 [00:08<00:12,  3.02s/it]
# Processing videos for vacant:  71%|██████████████████████████████████████▌               | 5/7 [00:12<00:04,  2.47s/it]
# Processing videos for vacant: 100%|██████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.36s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▌| 1985/2000 [13:40:35<04:22, 17.53s/it]
# Processing videos for vague:   0%|                                                               | 0/7 [00:00<?, ?it/s]
# Processing videos for vague:  29%|███████████████▋                                       | 2/7 [00:04<00:10,  2.04s/it]
# Processing videos for vague:  43%|███████████████████████▌                               | 3/7 [00:08<00:12,  3.15s/it]
# Processing videos for vague:  71%|███████████████████████████████████████▎               | 5/7 [00:12<00:05,  2.55s/it]
# Processing videos for vague: 100%|███████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.41s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▌| 1986/2000 [13:40:53<04:04, 17.49s/it]
# Processing videos for valley:   0%|                                                              | 0/7 [00:00<?, ?it/s]
# Processing videos for valley:  29%|███████████████▍                                      | 2/7 [00:04<00:11,  2.33s/it]
# Processing videos for valley:  43%|███████████████████████▏                              | 3/7 [00:09<00:12,  3.17s/it]
# Processing videos for valley:  71%|██████████████████████████████████████▌               | 5/7 [00:13<00:05,  2.60s/it]
# Processing videos for valley: 100%|██████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.41s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▋| 1987/2000 [13:41:10<03:47, 17.52s/it]
# Processing videos for vampire:   0%|                                                             | 0/7 [00:00<?, ?it/s]
# Processing videos for vampire:  14%|███████▌                                             | 1/7 [00:04<00:25,  4.29s/it]
# Processing videos for vampire:  29%|███████████████▏                                     | 2/7 [00:08<00:21,  4.21s/it]
# Processing videos for vampire:  43%|██████████████████████▋                              | 3/7 [00:12<00:17,  4.31s/it]
# Processing videos for vampire:  71%|█████████████████████████████████████▊               | 5/7 [00:16<00:06,  3.02s/it]
# Processing videos for vampire: 100%|█████████████████████████████████████████████████████| 7/7 [00:21<00:00,  2.65s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▋| 1988/2000 [13:41:32<03:44, 18.67s/it]
# Processing videos for very:   0%|                                                                | 0/7 [00:00<?, ?it/s]
# Processing videos for very:  14%|████████                                                | 1/7 [00:05<00:30,  5.06s/it]
# Processing videos for very:  29%|████████████████                                        | 2/7 [00:09<00:23,  4.72s/it]
# Processing videos for very:  43%|████████████████████████                                | 3/7 [00:14<00:18,  4.67s/it]
# Processing videos for very:  57%|████████████████████████████████                        | 4/7 [00:18<00:14,  4.71s/it]
# Processing videos for very:  86%|████████████████████████████████████████████████        | 6/7 [00:23<00:03,  3.35s/it]
# Processing videos for very: 100%|████████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.63s/it]
# Processing classes:  99%|██████████████████████████████████████████████████████▋| 1989/2000 [13:41:59<03:54, 21.35s/it]
# Processing videos for vice president:   0%|                                                      | 0/7 [00:00<?, ?it/s]
# Processing videos for vice president:  29%|█████████████▏                                | 2/7 [00:04<00:10,  2.14s/it]
# Processing videos for vice president:  43%|███████████████████▋                          | 3/7 [00:09<00:12,  3.21s/it]
# Processing videos for vice president:  71%|████████████████████████████████▊             | 5/7 [00:13<00:05,  2.59s/it]
# Processing videos for vice president: 100%|██████████████████████████████████████████████| 7/7 [00:17<00:00,  2.39s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▋| 1990/2000 [13:42:17<03:21, 20.17s/it]
# Processing videos for viewpoint:   0%|                                                           | 0/7 [00:00<?, ?it/s]
# Processing videos for viewpoint:  29%|██████████████▌                                    | 2/7 [00:04<00:11,  2.27s/it]
# Processing videos for viewpoint:  57%|█████████████████████████████▏                     | 4/7 [00:08<00:06,  2.20s/it]
# Processing videos for viewpoint:  71%|████████████████████████████████████▍              | 5/7 [00:13<00:05,  2.81s/it]
# Processing videos for viewpoint:  86%|███████████████████████████████████████████▋       | 6/7 [00:17<00:03,  3.25s/it]
# Processing videos for viewpoint: 100%|███████████████████████████████████████████████████| 7/7 [00:21<00:00,  3.58s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▊| 1991/2000 [13:42:38<03:05, 20.66s/it]
# Processing videos for visualize:   0%|                                                           | 0/7 [00:00<?, ?it/s]
# Processing videos for visualize:  29%|██████████████▌                                    | 2/7 [00:04<00:10,  2.14s/it]
# Processing videos for visualize:  43%|█████████████████████▊                             | 3/7 [00:08<00:12,  3.01s/it]
# Processing videos for visualize:  57%|█████████████████████████████▏                     | 4/7 [00:12<00:10,  3.46s/it]
# Processing videos for visualize:  86%|███████████████████████████████████████████▋       | 6/7 [00:16<00:02,  2.76s/it]
# Processing videos for visualize: 100%|███████████████████████████████████████████████████| 7/7 [00:21<00:00,  3.17s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▊| 1992/2000 [13:43:00<02:46, 20.83s/it]
# Processing videos for vlog:   0%|                                                                | 0/7 [00:00<?, ?it/s]
# Processing videos for vlog:  14%|████████                                                | 1/7 [00:04<00:24,  4.15s/it]
# Processing videos for vlog:  29%|████████████████                                        | 2/7 [00:08<00:21,  4.28s/it]
# Processing videos for vlog:  43%|████████████████████████                                | 3/7 [00:12<00:17,  4.36s/it]
# Processing videos for vlog:  86%|████████████████████████████████████████████████        | 6/7 [00:17<00:02,  2.42s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▊| 1993/2000 [13:43:17<02:18, 19.77s/it]
# Processing videos for volleyball:   0%|                                                          | 0/7 [00:00<?, ?it/s]
# Processing videos for volleyball:  29%|██████████████▎                                   | 2/7 [00:04<00:10,  2.08s/it]
# Processing videos for volleyball:  57%|████████████████████████████▌                     | 4/7 [00:08<00:06,  2.11s/it]
# Processing videos for volleyball:  71%|███████████████████████████████████▋              | 5/7 [00:13<00:05,  2.87s/it]
# Processing videos for volleyball:  86%|██████████████████████████████████████████▊       | 6/7 [00:17<00:03,  3.39s/it]
# Processing videos for volleyball: 100%|██████████████████████████████████████████████████| 7/7 [00:22<00:00,  3.72s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▊| 1994/2000 [13:43:39<02:03, 20.51s/it]
# Processing videos for w:   0%|                                                                   | 0/7 [00:00<?, ?it/s]
# Processing videos for w:  29%|████████████████▊                                          | 2/7 [00:04<00:10,  2.19s/it]
# Processing videos for w:  43%|█████████████████████████▎                                 | 3/7 [00:09<00:13,  3.25s/it]
# Processing videos for w:  71%|██████████████████████████████████████████▏                | 5/7 [00:13<00:05,  2.68s/it]
# Processing videos for w: 100%|███████████████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.45s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▊| 1995/2000 [13:43:57<01:38, 19.72s/it]
# Processing videos for washington:   0%|                                                          | 0/7 [00:00<?, ?it/s]
# Processing videos for washington:  43%|█████████████████████▍                            | 3/7 [00:04<00:06,  1.58s/it]
# Processing videos for washington:  57%|████████████████████████████▌                     | 4/7 [00:09<00:07,  2.59s/it]
# Processing videos for washington:  71%|███████████████████████████████████▋              | 5/7 [00:14<00:06,  3.21s/it]
# Processing videos for washington:  86%|██████████████████████████████████████████▊       | 6/7 [00:18<00:03,  3.56s/it]
# Processing videos for washington: 100%|██████████████████████████████████████████████████| 7/7 [00:22<00:00,  3.88s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▉| 1996/2000 [13:44:20<01:22, 20.70s/it]
# Processing videos for waterfall:   0%|                                                           | 0/7 [00:00<?, ?it/s]
# Processing videos for waterfall:  29%|██████████████▌                                    | 2/7 [00:04<00:11,  2.27s/it]
# Processing videos for waterfall:  43%|█████████████████████▊                             | 3/7 [00:09<00:13,  3.26s/it]
# Processing videos for waterfall:  57%|█████████████████████████████▏                     | 4/7 [00:13<00:11,  3.80s/it]
# Processing videos for waterfall:  86%|███████████████████████████████████████████▋       | 6/7 [00:18<00:02,  2.93s/it]
# Processing videos for waterfall: 100%|███████████████████████████████████████████████████| 7/7 [00:22<00:00,  3.26s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▉| 1997/2000 [13:44:42<01:03, 21.19s/it]
# Processing videos for weigh:   0%|                                                               | 0/7 [00:00<?, ?it/s]
# Processing videos for weigh:  57%|███████████████████████████████▍                       | 4/7 [00:04<00:03,  1.06s/it]
# Processing videos for weigh:  71%|███████████████████████████████████████▎               | 5/7 [00:08<00:03,  1.86s/it]
# Processing videos for weigh: 100%|███████████████████████████████████████████████████████| 7/7 [00:12<00:00,  2.00s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▉| 1998/2000 [13:44:55<00:37, 18.66s/it]
# Processing videos for wheelchair:   0%|                                                          | 0/7 [00:00<?, ?it/s]
# Processing videos for wheelchair:  14%|███████▏                                          | 1/7 [00:04<00:28,  4.75s/it]
# Processing videos for wheelchair:  43%|█████████████████████▍                            | 3/7 [00:08<00:11,  2.77s/it]
# Processing videos for wheelchair:  57%|████████████████████████████▌                     | 4/7 [00:13<00:09,  3.32s/it]
# Processing videos for wheelchair: 100%|██████████████████████████████████████████████████| 7/7 [00:17<00:00,  2.18s/it]
# Processing classes: 100%|██████████████████████████████████████████████████████▉| 1999/2000 [13:45:13<00:18, 18.32s/it]
# Processing videos for whistle:   0%|                                                             | 0/7 [00:00<?, ?it/s]
# Processing videos for whistle:  43%|██████████████████████▋                              | 3/7 [00:04<00:05,  1.45s/it]
# Processing videos for whistle:  71%|█████████████████████████████████████▊               | 5/7 [00:08<00:03,  1.78s/it]
# Processing videos for whistle: 100%|█████████████████████████████████████████████████████| 7/7 [00:12<00:00,  1.92s/it]
# Processing classes: 100%|███████████████████████████████████████████████████████| 2000/2000 [13:45:26<00:00, 24.76s/it]

# %%
# Get model parameters
num_classes = len(preprocessor.class_map)
sequence_length = X_train.shape[1]
feature_dim = X_train.shape[2]

# %%
# Initialize and build model
print("Building model...")
sign_language_model = SignLanguageModel(num_classes, sequence_length, feature_dim)
model = sign_language_model.build_model()
model = sign_language_model.compile_model(model)
# Out:
# Building model...

# %%
# Train model
print("Training model...")
history = sign_language_model.train_model(model, X_train, y_train, X_val, y_val)
# Out:
# Training model...
#
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50

# %%
test_loss, test_accuracy = model.evaluate(X_val, y_val)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 75/75 [==============================] - 4s 28ms/step - loss: 5.6033 - accuracy: 0.0547
# Test accuracy: 0.0547

# %%
# Save model and preprocessing parameters
print("Saving model and parameters...")
model.save('sign_language_model.h5')
# Out:
# Saving model and parameters...
# C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Get model predictions for validation set
y_pred = np.argmax(model.predict(X_val), axis=1)

# If your y_val is one-hot encoded, convert it to class indices
if len(y_val.shape) > 1:  # Check if one-hot encoded
    y_val_classes = np.argmax(y_val, axis=1)
else:
    y_val_classes = y_val

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_val_classes, y_pred)

# Initialize metrics dictionary
metrics = {}

try:
    class_names = list(sign_language_model.preprocessor.class_map.keys())
except:
    class_names = [str(i) for i in range(len(np.unique(y_val_classes)))]
# Out:
# 75/75 [==============================] - 2s 23ms/step

# %%
# Calculate metrics for each class
for i, class_name in enumerate(class_names):
    # True Positives: diagonal elements
    tp = conf_matrix[i, i]
    
    # False Positives: sum of column i (excluding diagonal)
    fp = np.sum(conf_matrix[:, i]) - tp
    
    # False Negatives: sum of row i (excluding diagonal)
    fn = np.sum(conf_matrix[i, :]) - tp
    
    # True Negatives: sum of all elements excluding row i and column i
    tn = np.sum(conf_matrix) - (tp + fp + fn)
    
    # Calculate additional metrics
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    metrics[class_name] = {
        'true_positive': int(tp),
        'false_positive': int(fp),
        'true_negative': int(tn),
        'false_negative': int(fn),
        'precision': float(precision),
        'recall': float(recall),
        'f1_score': float(f1)
    }

# %%
# Calculate overall metrics
overall_metrics = {
    'accuracy': float(np.mean(y_pred == y_val_classes)),
    'macro_precision': float(np.mean([m['precision'] for m in metrics.values()])),
    'macro_recall': float(np.mean([m['recall'] for m in metrics.values()])),
    'macro_f1': float(np.mean([m['f1_score'] for m in metrics.values()]))
}

# %%
# Create comprehensive report
report = {
    'overall_metrics': overall_metrics,
    'class_metrics': metrics
}

# Print training history metrics if available
if history:
    print("Training History Metrics:")
    print("=" * 50)
    print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
    print(f"Final Training Accuracy: {history.history['accuracy'][-1]:.4f}")
    print(f"Final Validation Loss: {history.history['val_loss'][-1]:.4f}")
    print(f"Final Training Loss: {history.history['loss'][-1]:.4f}\n")

# Print overall metrics
print("\nModel Evaluation Report")
print("=" * 50)
print("\nOverall Metrics:")
print("-" * 20)
for metric, value in report['overall_metrics'].items():
    print(f"{metric.replace('_', ' ').title()}: {value:.4f}")

# Print per-class metrics
print("\nPer-Class Metrics:")
print("-" * 20)

# Calculate maximum class name length for formatting
max_name_length = max(len(str(name)) for name in report['class_metrics'].keys())

# Print header
header = (f"{'Class':<{max_name_length}} | {'TP':>5} | {'FP':>5} | "
         f"{'TN':>5} | {'FN':>5} | {'Precision':>9} | {'Recall':>9} | {'F1':>9}")
print(header)
print("-" * len(header))

# Print metrics for each class
for class_name, metrics in report['class_metrics'].items():
    print(
        f"{str(class_name):<{max_name_length}} | "
        f"{metrics['true_positive']:5d} | "
        f"{metrics['false_positive']:5d} | "
        f"{metrics['true_negative']:5d} | "
        f"{metrics['false_negative']:5d} | "
        f"{metrics['precision']:9.4f} | "
        f"{metrics['recall']:9.4f} | "
        f"{metrics['f1_score']:9.4f}"
    )
# Out:
# Training History Metrics:
# ==================================================
# Final Validation Accuracy: 0.0564
# Final Training Accuracy: 0.3148
# Final Validation Loss: 6.2727
# Final Training Loss: 2.7227
#
#
# Model Evaluation Report
# ==================================================
#
# Overall Metrics:
# --------------------
# Accuracy: 0.0547
# Macro Precision: 0.0376
# Macro Recall: 0.0519
# Macro F1: 0.0376
#
# Per-Class Metrics:
# --------------------
# Class |    TP |    FP |    TN |    FN | Precision |    Recall |        F1
# -------------------------------------------------------------------------
# 0    |     0 |     0 |  2393 |     2 |    0.0000 |    0.0000 |    0.0000
# 1    |     1 |    10 |  2380 |     4 |    0.0909 |    0.2000 |    0.1250
# 2    |     0 |     0 |  2392 |     3 |    0.0000 |    0.0000 |    0.0000
# 3    |     0 |     0 |  2388 |     7 |    0.0000 |    0.0000 |    0.0000
# 4    |     0 |     4 |  2389 |     2 |    0.0000 |    0.0000 |    0.0000
# 5    |     0 |     0 |  2394 |     1 |    0.0000 |    0.0000 |    0.0000
# 6    |     0 |     4 |  2387 |     4 |    0.0000 |    0.0000 |    0.0000
# 7    |     0 |     8 |  2381 |     6 |    0.0000 |    0.0000 |    0.0000
# 8    |     0 |     0 |  2391 |     4 |    0.0000 |    0.0000 |    0.0000
# 9    |     0 |     1 |  2392 |     2 |    0.0000 |    0.0000 |    0.0000
# 10   |     0 |     1 |  2392 |     2 |    0.0000 |    0.0000 |    0.0000
# 11   |     0 |     3 |  2391 |     1 |    0.0000 |    0.0000 |    0.0000
#