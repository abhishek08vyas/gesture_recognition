# %%
import cv2
import torch
import time
import numpy as np
from ultralytics import YOLO
import mediapipe as mp

# %%
def initialize_label_map():
    """Initialize the label map for gestures detected by the YOLO model"""
    return {
        0: 'grabbing', 1: 'grip', 2: 'holy', 3: 'point', 4: 'call', 5: 'three3', 
        6: 'timeout', 7: 'xsign', 8: 'hand_heart', 9: 'hand_heart2', 10: 'little_finger', 
        11: 'middle_finger', 12: 'take_picture', 13: 'dislike', 14: 'fist', 15: 'four', 
        16: 'like', 17: 'mute', 18: 'ok', 19: 'one', 20: 'palm', 21: 'peace', 
        22: 'peace_inverted', 23: 'rock', 24: 'stop', 25: 'stop_inverted', 26: 'three', 
        27: 'three2', 28: 'two_up', 29: 'two_up_inverted', 30: 'three_gun', 
        31: 'thumb_index', 32: 'thumb_index2', 33: 'no_gesture'
    }

# %%
class HandGestureRecognizer:
    def __init__(self, model_path='./YOLOv10n_gestures.pt'):
        # Initialize YOLO model
        self.device = torch.device("cuda" if torch.cuda.is_available() else 
                                 "mps" if torch.backends.mps.is_available() else "cpu")
        print(f"Using device: {self.device}")
        self.model = YOLO(model_path).to(self.device)
        
        # Initialize MediaPipe
        self.mp_hands = mp.solutions.hands
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.hands = self.mp_hands.Hands(
            static_image_mode=False,
            max_num_hands=2,
            min_detection_confidence=0.5,
            min_tracking_confidence=0.5
        )
        
        # Initialize label map
        self.label_map = initialize_label_map()
        
    def process_frame(self, frame):
        # Convert the BGR image to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Process the frame with MediaPipe
        results_mp = self.hands.process(rgb_frame)
        
        # Run YOLO detection
        results_yolo = self.model(frame)
        
        # Draw MediaPipe hand landmarks
        if results_mp.multi_hand_landmarks:
            for hand_landmarks in results_mp.multi_hand_landmarks:
                self.mp_drawing.draw_landmarks(
                    frame,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style()
                )
                
        # Process YOLO results
        for result in results_yolo:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                confidence = box.conf[0].cpu().numpy()
                class_id = int(box.cls[0].cpu().numpy())
                
                if confidence > 0.5:
                    predicted_gesture = self.label_map.get(class_id, "Unknown Gesture")
                    
                    # Draw bounding box
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    
                    # Add prediction text
                    text = f"{predicted_gesture} ({confidence:.2f})"
                    cv2.putText(frame, text, (int(x1), int(y1) - 10),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        return frame

    def real_time_recognition(self):
        cap = cv2.VideoCapture(0)
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
        
        prev_time = 0
        
        print("Starting real-time gesture recognition. Press 'q' to quit.")
        print("Available signs:", ", ".join(self.label_map.values()))
        
        try:
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    print("Failed to grab frame")
                    break
                
                # Calculate FPS
                current_time = time.time()
                fps = 1 / (current_time - prev_time)
                prev_time = current_time
                
                # Process frame
                frame = self.process_frame(frame)
                
                # Display FPS
                cv2.putText(frame, f"FPS: {int(fps)}", (550, 30),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
                
                # Display the frame
                cv2.imshow('Hand Gesture Recognition', frame)
                
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
                
        finally:
            cap.release()
            cv2.destroyAllWindows()

# %%
try:
    recognizer = HandGestureRecognizer()
    recognizer.real_time_recognition()
except Exception as e:
    print(f"An error occurred: {str(e)}")
    cv2.VideoCapture(0).release()
    cv2.destroyAllWindows()
# Out:
# Using device: cuda
# Starting real-time gesture recognition. Press 'q' to quit.
# Available signs: grabbing, grip, holy, point, call, three3, timeout, xsign, hand_heart, hand_heart2, little_finger, middle_finger, take_picture, dislike, fist, four, like, mute, ok, one, palm, peace, peace_inverted, rock, stop, stop_inverted, three, three2, two_up, two_up_inverted, three_gun, thumb_index, thumb_index2, no_gesture
#
# 0: 480x640 (no detections), 102.9ms
# Speed: 9.1ms preprocess, 102.9ms inference, 19.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.1ms
# Speed: 4.9ms preprocess, 45.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.9ms
# Speed: 4.0ms preprocess, 46.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 3.9ms preprocess, 50.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 3.0ms preprocess, 51.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 4.9ms preprocess, 49.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 6.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.2ms
# Speed: 3.9ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.4ms
# Speed: 5.4ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.3ms
# Speed: 5.5ms preprocess, 77.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.1ms
# Speed: 3.0ms preprocess, 31.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.9ms
# Speed: 4.5ms preprocess, 30.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.0ms
# Speed: 4.3ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.0ms
# Speed: 3.9ms preprocess, 29.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 3.9ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.5ms
# Speed: 3.0ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.2ms
# Speed: 4.0ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.3ms
# Speed: 3.0ms preprocess, 30.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# C:\Users\abhis\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 0: 480x640 1 four, 1 palm, 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 33.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.2ms
# Speed: 3.1ms preprocess, 30.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 77.5ms
# Speed: 6.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 3.9ms preprocess, 30.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 34.5ms
# Speed: 4.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 29.5ms
# Speed: 4.1ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.9ms
# Speed: 5.0ms preprocess, 30.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.4ms
# Speed: 4.4ms preprocess, 30.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.3ms
# Speed: 3.9ms preprocess, 30.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.1ms
# Speed: 3.9ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.5ms
# Speed: 4.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.3ms
# Speed: 4.0ms preprocess, 30.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 3.9ms preprocess, 30.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.1ms
# Speed: 4.1ms preprocess, 30.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.6ms
# Speed: 3.0ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 29.6ms
# Speed: 3.0ms preprocess, 29.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 32.6ms
# Speed: 2.9ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.2ms
# Speed: 3.9ms preprocess, 31.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.2ms
# Speed: 4.9ms preprocess, 30.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 3.5ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.6ms
# Speed: 4.1ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.2ms
# Speed: 3.0ms preprocess, 31.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.6ms
# Speed: 4.0ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.4ms
# Speed: 4.0ms preprocess, 31.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.9ms
# Speed: 4.1ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.6ms
# Speed: 3.2ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 31.0ms
# Speed: 2.9ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 29.2ms
# Speed: 3.4ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 28.6ms
# Speed: 2.9ms preprocess, 28.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 30.0ms
# Speed: 2.5ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 four, 29.4ms
# Speed: 3.0ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.1ms
# Speed: 3.4ms preprocess, 29.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.8ms
# Speed: 4.3ms preprocess, 29.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.1ms
# Speed: 3.0ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.3ms
# Speed: 3.2ms preprocess, 29.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.0ms
# Speed: 4.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 22.4ms
# Speed: 3.3ms preprocess, 22.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 26.0ms
# Speed: 2.3ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 26.8ms
# Speed: 2.5ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 1 fist, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 1 fist, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 19.9ms
# Speed: 2.1ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 call, 1 like, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 33.4ms
# Speed: 3.9ms preprocess, 33.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.3ms
# Speed: 4.3ms preprocess, 32.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.5ms
# Speed: 3.5ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.1ms
# Speed: 3.6ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.4ms
# Speed: 4.4ms preprocess, 32.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.1ms
# Speed: 3.0ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.4ms
# Speed: 3.0ms preprocess, 32.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.7ms
# Speed: 3.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 34.8ms
# Speed: 3.0ms preprocess, 34.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 32.0ms
# Speed: 4.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.5ms
# Speed: 3.5ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.4ms
# Speed: 4.2ms preprocess, 31.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 29.7ms
# Speed: 3.9ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 30.8ms
# Speed: 3.1ms preprocess, 30.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.9ms
# Speed: 3.1ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 34.0ms
# Speed: 3.7ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.0ms
# Speed: 3.1ms preprocess, 31.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 31.1ms
# Speed: 4.1ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 call, 1 like, 30.8ms
# Speed: 4.1ms preprocess, 30.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 30.7ms
# Speed: 3.0ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 like, 30.6ms
# Speed: 4.6ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.8ms
# Speed: 3.0ms preprocess, 30.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.3ms
# Speed: 4.7ms preprocess, 30.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 1 stop, 29.2ms
# Speed: 5.0ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 two_up, 30.8ms
# Speed: 3.0ms preprocess, 30.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.0ms
# Speed: 3.1ms preprocess, 31.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 30.3ms
# Speed: 4.0ms preprocess, 30.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 29.4ms
# Speed: 3.1ms preprocess, 29.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 30.2ms
# Speed: 4.0ms preprocess, 30.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 29.8ms
# Speed: 3.0ms preprocess, 29.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 29.4ms
# Speed: 3.0ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 30.5ms
# Speed: 4.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.8ms
# Speed: 3.0ms preprocess, 31.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 32.1ms
# Speed: 3.5ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 32.0ms
# Speed: 4.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 33.5ms
# Speed: 4.0ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 30.5ms
# Speed: 3.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 30.4ms
# Speed: 3.0ms preprocess, 30.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.8ms
# Speed: 2.9ms preprocess, 31.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.9ms
# Speed: 3.6ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 32.4ms
# Speed: 3.0ms preprocess, 32.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.3ms
# Speed: 3.0ms preprocess, 31.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 33.8ms
# Speed: 3.4ms preprocess, 33.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 33.0ms
# Speed: 2.9ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 29.4ms
# Speed: 4.0ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 31.4ms
# Speed: 3.0ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 18.2ms
# Speed: 3.0ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 peace, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 four, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 four, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 16.9ms
# Speed: 1.1ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.2ms
# Speed: 4.0ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.5ms
# Speed: 2.9ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.0ms
# Speed: 4.1ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.9ms
# Speed: 3.0ms preprocess, 30.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 1 stop, 30.1ms
# Speed: 4.1ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.7ms
# Speed: 4.0ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.6ms
# Speed: 3.3ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 19.8ms
# Speed: 1.6ms preprocess, 19.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 26.0ms
# Speed: 3.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 26.5ms
# Speed: 2.2ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 23.2ms
# Speed: 3.0ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 38.0ms
# Speed: 4.9ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 32.9ms
# Speed: 4.2ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.4ms
# Speed: 3.9ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 32.5ms
# Speed: 5.0ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 31.9ms
# Speed: 5.1ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 45.5ms
# Speed: 6.0ms preprocess, 45.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 36.0ms
# Speed: 2.9ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 32.5ms
# Speed: 3.7ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 31.2ms
# Speed: 2.9ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.0ms
# Speed: 4.0ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.5ms
# Speed: 2.9ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.5ms
# Speed: 4.0ms preprocess, 30.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 2.5ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.5ms
# Speed: 6.5ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 1 fist, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grip, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.0ms
# Speed: 5.0ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 call, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 no_gesture, 32.0ms
# Speed: 5.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.0ms
# Speed: 1.9ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 26.2ms
# Speed: 3.0ms preprocess, 26.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 37.7ms
# Speed: 3.0ms preprocess, 37.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 stop, 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 stop, 35.6ms
# Speed: 4.0ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.6ms
# Speed: 3.3ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.5ms
# Speed: 4.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.5ms
# Speed: 3.6ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.1ms
# Speed: 3.4ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.1ms
# Speed: 3.9ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.1ms
# Speed: 3.0ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.7ms
# Speed: 4.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 32.0ms
# Speed: 3.9ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.1ms
# Speed: 3.9ms preprocess, 30.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.9ms
# Speed: 5.1ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 1 palm, 30.4ms
# Speed: 3.1ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 30.5ms
# Speed: 3.0ms preprocess, 30.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 29.0ms
# Speed: 3.5ms preprocess, 29.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 30.0ms
# Speed: 3.5ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 29.9ms
# Speed: 2.9ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 29.2ms
# Speed: 3.0ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 27.5ms
# Speed: 3.0ms preprocess, 27.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 19.0ms
# Speed: 1.9ms preprocess, 19.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 22.0ms
# Speed: 4.6ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 23.2ms
# Speed: 2.5ms preprocess, 23.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 28.2ms
# Speed: 3.1ms preprocess, 28.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grabbing, 1 fist, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.7ms
# Speed: 4.0ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.4ms
# Speed: 3.1ms preprocess, 30.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.8ms
# Speed: 3.0ms preprocess, 29.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 31.1ms
# Speed: 4.9ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 30.7ms
# Speed: 3.7ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 29.0ms
# Speed: 2.9ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 20.0ms
# Speed: 3.9ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 20.6ms
# Speed: 3.1ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 palm, 14.0ms
# Speed: 3.3ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 17.6ms
# Speed: 2.4ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fist, 34.8ms
# Speed: 4.3ms preprocess, 34.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 fists, 34.5ms
# Speed: 4.5ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.0ms
# Speed: 4.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 4.0ms preprocess, 29.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.4ms
# Speed: 3.2ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
